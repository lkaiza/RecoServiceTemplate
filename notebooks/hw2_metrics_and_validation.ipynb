# %%
# pip install rectools

# %%
# pip install -U Jinja2

# %%
from copy import deepcopy
import pandas as pd
import numpy as np

import requests
from tqdm.auto import tqdm
import time

from rectools import Columns
from rectools.models import RandomModel, PopularModel
from rectools.dataset import Interactions, Dataset
from rectools.model_selection import TimeRangeSplitter
from rectools.metrics import (
    Precision,
    Recall,
    MRR,
    MAP,
    Serendipity,
    MeanInvUserFreq,
    calc_metrics,
)

# %%
K_RECOS = 10

# %% [markdown]
# # Load data

# %%
data_path = 'data/kion_train'

# %%
interactions = pd.read_csv(f'{data_path}/interactions.csv', parse_dates=["last_watch_dt"])

interactions.rename(
    columns={
        'last_watch_dt': Columns.Datetime,
        'total_dur': Columns.Weight
    }, 
    inplace=True) 

users = pd.read_csv(f'{data_path}/users.csv')
items = pd.read_csv(f'{data_path}/items.csv')

# %% [markdown]
# # Functions

# %%
def train_models(interactions, models, metrics, k, cv):
    """
    Calculate metrics based on cross-validation
    
    Parameters
    -----------
    interactions: pd.DataFrame with User-Item interactions
    models: dict with initialized models
    metrics: dict with initialized metrics
    k: number of recommendations to generate
    cv: initialized Splitter for cross validation
    """
    results = []
    fold_iterator = cv.split(Interactions(interactions), collect_fold_stats=True)

    for train_ids, test_ids, fold_info in tqdm((fold_iterator), total=cv.n_splits):
        print(f"\n==================== Fold {fold_info['i_split']}")
        print(fold_info)

        # 1. Create Dataset
        df_train = interactions.iloc[train_ids]
        dataset = Dataset.construct(df_train)

        df_test = interactions.iloc[test_ids][Columns.UserItem]
        test_users = np.unique(df_test[Columns.User])

        catalog = df_train[Columns.Item].unique()

        for model_name, model in models.items():
            # 2-3. Fit model and log the training time
            start_time = time.time()
            model.fit(dataset)
            end_time = time.time()
            recos = model.recommend(
                users=test_users,
                dataset=dataset,
                k=k,
                filter_viewed=True,
            )
            # 4. Calculate and save metrics
            metric_values = calc_metrics(
                metrics,
                reco=recos,
                interactions=df_test,
                prev_interactions=df_train,
                catalog=catalog,
            )
            models[model_name] = deepcopy(model)
            res = {"fold": fold_info["i_split"], "model": model_name, "time": end_time - start_time}
            res.update(metric_values)
            results.append(res)
            
    return pd.DataFrame(results)

# %%
def visualize(model, dataset, user_ids, item_data, k):
    """
    Visual analysis of recommendations
    
    Parameters
    -----------
    model: fitted model
    metrics: rectools Dataset
    user_ids: list of selected user_ids to view
    item_data: information about items that is important to reflect for visual analysis (e.g. name)
    k: number of recommendations to generate
    """
    cols_ext = [Columns.User, Columns.Item, 'is_watched']
    cols = cols_ext[:-1]
    
    # 1. Get recos
    recos = model.recommend(
                users=user_ids,
                dataset=dataset,
                k=k,
                filter_viewed=True,
    )
    recos['is_watched'] = False
    
    # 2. Get watched items
    watched = dataset.interactions.df
    watched = watched.loc[watched[Columns.User].isin(user_ids), cols]
    watched['is_watched'] = True
    
    # 3. Merge items from previous steps and add item's features
    un = pd.concat([recos[cols_ext], watched[cols_ext]], axis=0)
    
    cnt = dataset.interactions.df[cols].groupby([Columns.Item]).count()
    cnt.reset_index(inplace=True)
    cnt.columns = [Columns.Item, 'views_count']
    
    res = un.merge(item_data, how='left', on=Columns.Item,) \
            .merge(cnt, on=Columns.Item,) \
            .sort_values([Columns.User, 'is_watched', 'views_count'], ascending=False)
    return res

# %% [markdown]
# # Test our fuctions

# %% [markdown]
# ## Cross validation

# %%
n_splits = 3

cv = TimeRangeSplitter(
    test_size="7D",
    n_splits=n_splits,
    filter_already_seen=True,
    filter_cold_items=True,
    filter_cold_users=True,
)

# Take few simple models to compare
models = {
    "random": RandomModel(random_state=32),
    "popular": PopularModel(),
}

# We will calculate several classic (precision@k and recall@k) and "beyond accuracy" metrics
metrics = {
    "prec@1": Precision(k=1),
    "prec@5": Precision(k=5),
    "prec@10": Precision(k=10),
    "recall@1": Recall(k=1),
    "recall@5": Recall(k=5),
    "recall@10": Recall(k=10),
    "MRR@1": MRR(k=1),
    "MRR@5": MRR(k=5),
    "MRR@10": MRR(k=10),
    "MAP@1": MAP(k=1),
    "MAP@5": MAP(k=5),
    "MAP@10": MAP(k=10),
    "Serendipity@1": Serendipity(k=1),
    "Serendipity@5": Serendipity(k=5),
    "Serendipity@10": Serendipity(k=10),
    "MeanInvUserFreq@1": MeanInvUserFreq(k=1),
    "MeanInvUserFreq@5": MeanInvUserFreq(k=5),
    "MeanInvUserFreq@10": MeanInvUserFreq(k=10),
}

# %%
res = train_models(interactions, models, metrics, K_RECOS, cv)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ==================== Fold 0
# {'i_split': 0, 'start': Timestamp('2021-08-02 00:00:00', freq='7D'), 'end': Timestamp('2021-08-09 00:00:00', freq='7D'), 'train': 4266013, 'train_users': 797423, 'train_items': 15237, 'test': 263681, 'test_users': 98184, 'test_items': 6602}
#
# ==================== Fold 1
# {'i_split': 1, 'start': Timestamp('2021-08-09 00:00:00', freq='7D'), 'end': Timestamp('2021-08-16 00:00:00', freq='7D'), 'train': 4649162, 'train_users': 850489, 'train_items': 15415, 'test': 279422, 'test_users': 103511, 'test_items': 6698}
#
# ==================== Fold 2
# {'i_split': 2, 'start': Timestamp('2021-08-16 00:00:00', freq='7D'), 'end': Timestamp('2021-08-23 00:00:00', freq='7D'), 'train': 5051815, 'train_users': 906071, 'train_items': 15577, 'test': 298878, 'test_users': 110076, 'test_items': 6679}

# %%
res
# Out:
#    fold    model      time    prec@1  recall@1    prec@5  recall@5   prec@10  \
# 0     0   random  0.000038  0.000244  0.000087  0.000228  0.000445  0.000214
# 1     0  popular  1.263931  0.084026  0.047435  0.054225  0.143095  0.035483
# 2     1   random  0.000579  0.000184  0.000051  0.000172  0.000278  0.000177
# 3     1  popular  1.512366  0.074466  0.041910  0.051848  0.136661  0.033572
# 4     2   random  0.000056  0.000236  0.000077  0.000207  0.000373  0.000188
# 5     2  popular  1.320657  0.070806  0.038816  0.051134  0.132482  0.032655
#
#    recall@10     MRR@1  ...    MRR@10     MAP@1     MAP@5    MAP@10  \
# 0   0.000771  0.000244  ...  0.000665  0.000087  0.000200  0.000243
# 1   0.181957  0.084026  ...  0.146332  0.047435  0.083190  0.089605
# 2   0.000620  0.000184  ...  0.000543  0.000051  0.000134  0.000179
# 3   0.172428  0.074466  ...  0.135420  0.041910  0.076906  0.082607
# 4   0.000688  0.000236  ...  0.000603  0.000077  0.000172  0.000212
# 5   0.166089  0.070806  ...  0.134058  0.038816  0.074789  0.080114
#
#    MeanInvUserFreq@1  MeanInvUserFreq@5  MeanInvUserFreq@10  Serendipity@1  \
# 0          15.599409          15.593514           15.593936       0.000008
# 1           2.401723           3.079837            3.711584       0.000002
# 2          15.602863          15.612800           15.611655       0.000004
# 3           2.373249           3.065811            3.712928       0.000002
# 4          15.640140          15.632653           15.633438       0.000007
# 5           2.356194           3.055289            3.715659       0.000002
#
#    Serendipity@5  Serendipity@10
# 0       0.000007        0.000007
# 1       0.000003        0.000002
# 2       0.000007        0.000007
# 3       0.000003        0.000002
# 4       0.000008        0.000007
# 5       0.000002        0.000002
#
# [6 rows x 21 columns]

# %%
# Aggregate metrics by folds and compare models
pivot_results = res.drop(columns="fold").groupby(["model"], sort=False).agg(["mean", "std"])
mean_metric_subset = [(metric, agg) for metric, agg in pivot_results.columns if agg == 'mean']
(
    pivot_results.style
    .highlight_min(subset=mean_metric_subset, color='lightcoral', axis=0)
    .highlight_max(subset=mean_metric_subset, color='lightgreen', axis=0)
)
# Out:
# <style type="text/css">
# #T_a2119_row0_col0, #T_a2119_row0_col2, #T_a2119_row0_col4, #T_a2119_row0_col6, #T_a2119_row0_col8, #T_a2119_row0_col10, #T_a2119_row0_col12, #T_a2119_row0_col14, #T_a2119_row0_col16, #T_a2119_row0_col18, #T_a2119_row0_col20, #T_a2119_row0_col22, #T_a2119_row0_col24, #T_a2119_row1_col26, #T_a2119_row1_col28, #T_a2119_row1_col30, #T_a2119_row1_col32, #T_a2119_row1_col34, #T_a2119_row1_col36 {
#   background-color: lightcoral;
# }
# #T_a2119_row0_col26, #T_a2119_row0_col28, #T_a2119_row0_col30, #T_a2119_row0_col32, #T_a2119_row0_col34, #T_a2119_row0_col36, #T_a2119_row1_col0, #T_a2119_row1_col2, #T_a2119_row1_col4, #T_a2119_row1_col6, #T_a2119_row1_col8, #T_a2119_row1_col10, #T_a2119_row1_col12, #T_a2119_row1_col14, #T_a2119_row1_col16, #T_a2119_row1_col18, #T_a2119_row1_col20, #T_a2119_row1_col22, #T_a2119_row1_col24 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a2119">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2119_level0_col0" class="col_heading level0 col0" colspan="2">time</th>
#       <th id="T_a2119_level0_col2" class="col_heading level0 col2" colspan="2">prec@1</th>
#       <th id="T_a2119_level0_col4" class="col_heading level0 col4" colspan="2">recall@1</th>
#       <th id="T_a2119_level0_col6" class="col_heading level0 col6" colspan="2">prec@5</th>
#       <th id="T_a2119_level0_col8" class="col_heading level0 col8" colspan="2">recall@5</th>
#       <th id="T_a2119_level0_col10" class="col_heading level0 col10" colspan="2">prec@10</th>
#       <th id="T_a2119_level0_col12" class="col_heading level0 col12" colspan="2">recall@10</th>
#       <th id="T_a2119_level0_col14" class="col_heading level0 col14" colspan="2">MRR@1</th>
#       <th id="T_a2119_level0_col16" class="col_heading level0 col16" colspan="2">MRR@5</th>
#       <th id="T_a2119_level0_col18" class="col_heading level0 col18" colspan="2">MRR@10</th>
#       <th id="T_a2119_level0_col20" class="col_heading level0 col20" colspan="2">MAP@1</th>
#       <th id="T_a2119_level0_col22" class="col_heading level0 col22" colspan="2">MAP@5</th>
#       <th id="T_a2119_level0_col24" class="col_heading level0 col24" colspan="2">MAP@10</th>
#       <th id="T_a2119_level0_col26" class="col_heading level0 col26" colspan="2">MeanInvUserFreq@1</th>
#       <th id="T_a2119_level0_col28" class="col_heading level0 col28" colspan="2">MeanInvUserFreq@5</th>
#       <th id="T_a2119_level0_col30" class="col_heading level0 col30" colspan="2">MeanInvUserFreq@10</th>
#       <th id="T_a2119_level0_col32" class="col_heading level0 col32" colspan="2">Serendipity@1</th>
#       <th id="T_a2119_level0_col34" class="col_heading level0 col34" colspan="2">Serendipity@5</th>
#       <th id="T_a2119_level0_col36" class="col_heading level0 col36" colspan="2">Serendipity@10</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a2119_level1_col0" class="col_heading level1 col0" >mean</th>
#       <th id="T_a2119_level1_col1" class="col_heading level1 col1" >std</th>
#       <th id="T_a2119_level1_col2" class="col_heading level1 col2" >mean</th>
#       <th id="T_a2119_level1_col3" class="col_heading level1 col3" >std</th>
#       <th id="T_a2119_level1_col4" class="col_heading level1 col4" >mean</th>
#       <th id="T_a2119_level1_col5" class="col_heading level1 col5" >std</th>
#       <th id="T_a2119_level1_col6" class="col_heading level1 col6" >mean</th>
#       <th id="T_a2119_level1_col7" class="col_heading level1 col7" >std</th>
#       <th id="T_a2119_level1_col8" class="col_heading level1 col8" >mean</th>
#       <th id="T_a2119_level1_col9" class="col_heading level1 col9" >std</th>
#       <th id="T_a2119_level1_col10" class="col_heading level1 col10" >mean</th>
#       <th id="T_a2119_level1_col11" class="col_heading level1 col11" >std</th>
#       <th id="T_a2119_level1_col12" class="col_heading level1 col12" >mean</th>
#       <th id="T_a2119_level1_col13" class="col_heading level1 col13" >std</th>
#       <th id="T_a2119_level1_col14" class="col_heading level1 col14" >mean</th>
#       <th id="T_a2119_level1_col15" class="col_heading level1 col15" >std</th>
#       <th id="T_a2119_level1_col16" class="col_heading level1 col16" >mean</th>
#       <th id="T_a2119_level1_col17" class="col_heading level1 col17" >std</th>
#       <th id="T_a2119_level1_col18" class="col_heading level1 col18" >mean</th>
#       <th id="T_a2119_level1_col19" class="col_heading level1 col19" >std</th>
#       <th id="T_a2119_level1_col20" class="col_heading level1 col20" >mean</th>
#       <th id="T_a2119_level1_col21" class="col_heading level1 col21" >std</th>
#       <th id="T_a2119_level1_col22" class="col_heading level1 col22" >mean</th>
#       <th id="T_a2119_level1_col23" class="col_heading level1 col23" >std</th>
#       <th id="T_a2119_level1_col24" class="col_heading level1 col24" >mean</th>
#       <th id="T_a2119_level1_col25" class="col_heading level1 col25" >std</th>
#       <th id="T_a2119_level1_col26" class="col_heading level1 col26" >mean</th>
#       <th id="T_a2119_level1_col27" class="col_heading level1 col27" >std</th>
#       <th id="T_a2119_level1_col28" class="col_heading level1 col28" >mean</th>
#       <th id="T_a2119_level1_col29" class="col_heading level1 col29" >std</th>
#       <th id="T_a2119_level1_col30" class="col_heading level1 col30" >mean</th>
#       <th id="T_a2119_level1_col31" class="col_heading level1 col31" >std</th>
#       <th id="T_a2119_level1_col32" class="col_heading level1 col32" >mean</th>
#       <th id="T_a2119_level1_col33" class="col_heading level1 col33" >std</th>
#       <th id="T_a2119_level1_col34" class="col_heading level1 col34" >mean</th>
#       <th id="T_a2119_level1_col35" class="col_heading level1 col35" >std</th>
#       <th id="T_a2119_level1_col36" class="col_heading level1 col36" >mean</th>
#       <th id="T_a2119_level1_col37" class="col_heading level1 col37" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2119_level0_row0" class="row_heading level0 row0" >random</th>
#       <td id="T_a2119_row0_col0" class="data row0 col0" >0.000225</td>
#       <td id="T_a2119_row0_col1" class="data row0 col1" >0.000307</td>
#       <td id="T_a2119_row0_col2" class="data row0 col2" >0.000221</td>
#       <td id="T_a2119_row0_col3" class="data row0 col3" >0.000033</td>
#       <td id="T_a2119_row0_col4" class="data row0 c

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Initialize params for tests

# %%
item_features_frames = []
user_ids = [666262, 672861, 955527]
cols = ['item_id', 'title', 'genres']

for feature in cols[1:]:
    feature_frame = items.reindex(columns=[Columns.Item, feature])
    feature_frame.columns = ["id", "value"]
    feature_frame["feature"] = feature
    item_features_frames.append(feature_frame)

item_features = pd.concat(item_features_frames)
item_features = item_features[item_features["id"].isin(interactions[Columns.Item])]

dataset = Dataset.construct(interactions, item_features_df=item_features, cat_item_features=cols[1:])

model_rand = models['random'].fit(dataset)
model_pop = models['popular'].fit(dataset)

# %% [markdown]
# ### Visualize random model results

# %%
vis_res_rand = visualize(model_rand, dataset, user_ids, items[cols], k=K_RECOS)
vis_res_rand
# Out:
#     user_id  item_id  is_watched  \
# 31   955527       21        True
# 19   955527      496       False
# 20   955527     4205       False
# 26   955527     3407       False
# 21   955527    10822       False
# 22   955527    10914       False
# 23   955527     3999       False
# 24   955527    14961       False
# 25   955527    13734       False
# 27   955527    14614       False
# 29   672861       25        True
# 30   672861       32        True
# 14   672861     3300       False
# 17   672861     3087       False
# 11   672861      473       False
# 13   672861     3927       False
# 15   672861     5334       False
# 10   672861     9457       False
# 12   672861    12736       False
# 18   672861     4416       False
# 16   672861    14273       False
# 28   666262       93        True
# 1    666262      619       False
# 9    666262     2816       False
# 4    666262     4041       False
# 3    666262     5967       False
# 5    666262     5701       False
# 2    666262    12618       False
# 0    666262    10101       False
# 6    666262     9738       False
# 7    666262    15247       False
# 8    666262    10004       False
#
#                                            title  \
# 31                                   Признание 5
# 19                           Воскресший Эртугрул
# 20          Дело гастронома №1 (Операция Беркут)
# 26                                Черный капитан
# 21                           Она защищает Родину
# 22                                  Великолепная
# 23                               Джиперс криперс
# 24                                Битва за Землю
# 25                 Сексуальный массаж и Фантазии
# 27                                         Настя
# 29                 Медвежонок Винни и его друзья
# 30                                В ритме сердца
# 14                    Антилопа Гну. Южная Африка
# 17                                Жуки - караоке
# 11                             Кто такой Букабу?
# 13                                    Помни меня
# 15                                 Boys and Toys
# 10                     Комната (жестовым языком)
# 12                                         Палач
# 18                                         Питер
# 16                           Влюбленный скорпион
# 28                          Дом ночных призраков
# 1   Новые приключения Аладдина (жестовым языком)
# 9                         Избави нас от лукавого
# 4                                     Фрилансеры
# 3                                Братья вне игры
# 5                     Алые паруса: Новая история
# 2                              Пропавшая грамота
# 0                            Возвращение Будулая
# 6                               Женщина в беде 3
# 7                       Гордость и предубеждение
# 8                                     Болванчики
#
#                                              genres  views_count
# 31                                     для взрослых       193123
# 19                      боевики, драмы, приключения         3108
# 20                                   драмы, русские          283
# 26                        боевики, русские, военные           31
# 21                        драмы, советские, военные           13
# 22                   зарубежные, комедии, мелодрамы            2
# 23                                  ужасы, триллеры            2
# 24             боевики, ужасы, фантастика, триллеры            2
# 25                                     для взрослых            1
# 27                               мелодрамы, комедии            1
# 29        мюзиклы, мультфильм, приключения, комедии       202457
# 30                        драмы, мюзиклы, мелодрамы       132865
# 14                                   документальное          835
# 17                                         no_genre          814
# 11       развлекательные, для детей, документальное          706
# 13                                 драмы, мелодрамы          597
# 15                                         no_genre           52
# 10                      драмы, зарубежные, триллеры           18
# 12                       драмы, зарубежные, комедии           12
# 18                             фэнтези, приключения            9
# 16    драмы, зарубежные, спорт, триллеры, мелодрамы            1
# 28           зарубежные, криминал, детективы, ужасы        68581
# 1                               зарубежные, комедии         6416
# 9                        ужасы, триллеры, детективы          181
# 4   криминал, детективы, драмы, зарубежные, боевики           30
# 3                                      драмы, спорт            8
# 5                                комедии, мелодрамы            6
# 2                                  фэнтези, комедии            4
# 0                                         мелодрамы            2
# 6                              детективы, мелодрамы            1
# 7                                  драмы, мелодрамы            1
# 8                  мультфильм, приключения, комедии            1

# %% [markdown]
# ### Visualize popular model results

# %%
vis_res_pop = visualize(model_pop, dataset, user_ids, items[cols], k=K_RECOS)
vis_res_pop
# Out:
#     user_id  item_id  is_watched                          title  \
# 33   955527       21        True                    Признание 5
# 26   955527      142       False                           Маша
# 14   955527     4151       False         Секреты семейной жизни
# 20   955527     2657       False                     Подслушано
# 29   955527     6809       False                          Дуров
# 23   955527     4880       False                          Афера
# 17   955527     3734       False   Прабабушка легкого поведения
# 2    955527    10440       False                    Хрустальный
# 8    955527     9728       False              Гнев человеческий
# 11   955527    13865       False                       Девятаев
# 5    955527    15297       False                Клиника счастья
# 31   672861       25        True  Медвежонок Винни и его друзья
# 32   672861       32        True                 В ритме сердца
# 25   672861      142       False                           Маша
# 13   672861     4151       False         Секреты семейной жизни
# 19   672861     2657       False                     Подслушано
# 28   672861     6809       False                          Дуров
# 22   672861     4880       False                          Афера
# 16   672861     3734       False   Прабабушка легкого поведения
# 1    672861    10440       False                    Хрустальный
# 7    672861     9728       False              Гнев человеческий
# 10   672861    13865       False                       Девятаев
# 4    672861    15297       False                Клиника счастья
# 30   666262       93        True           Дом ночных призраков
# 24   666262      142       False                           Маша
# 12   666262     4151       False         Секреты семейной жизни
# 18   666262     2657       False                     Подслушано
# 27   666262     6809       False                          Дуров
# 21   666262     4880       False                          Афера
# 15   666262     3734       False   Прабабушка легкого поведения
# 0    666262    10440       False                    Хрустальный
# 6    666262     9728       False              Гнев человеческий
# 9    666262    13865       False                       Девятаев
# 3    666262    15297       False                Клиника счастья
#
#                                        genres  views_count
# 33                               для взрослых       193123
# 26                            драмы, триллеры        55043
# 14                                    комедии          325
# 20                            драмы, триллеры          285
# 29                             документальное           96
# 23                                    комедии           39
# 17                                    комедии           23
# 2                         триллеры, детективы            7
# 8                           боевики, триллеры            7
# 11                драмы, военные, приключения            3
# 5                            драмы, мелодрамы            1
# 31  мюзиклы, мультфильм, приключения, комедии       202457
# 32                  драмы, мюзиклы, мелодрамы       132865
# 25                            драмы, триллеры        55043
# 13                                    комедии          325
# 19                            драмы, триллеры          285
# 28                             документальное           96
# 22                                    комедии           39
# 16                                    комедии           23
# 1                         триллеры, детективы            7
# 7                           боевики, триллеры            7
# 10                драмы, военные, приключения            3
# 4                            драмы, мелодрамы            1
# 30     зарубежные, криминал, детективы, ужасы        68581
# 24                            драмы, триллеры        55043
# 12                                    комедии          325
# 18                            драмы, триллеры          285
# 27                             документальное           96
# 21                                    комедии           39
# 15                                    комедии           23
# 0                         триллеры, детективы            7
# 6                           боевики, триллеры            7
# 9                 драмы, военные, приключения            3
# 3                            драмы, мелодрамы            1
